# %%
# !python3 -m lm.main data/test-run/ \
data/encoded/ \
data/sp-model.model \
--batch-size 18 \
--g-accum-gradients 2 \
--n-ctx 256 \
--n-embed 512 \
--n-head 4 \
--n-layer 3 \
--epochs 20 \
--log-every 100 \
--save-every 1000 \
--validate-every 1000
# Out:
# {
#     "argv": "/home/igorkarpov/Projects/github.com/semicontinuity/nlp/lopuhin_transformer_lm/lm/main.py data/test-run/ data/encoded/ data/sp-model.model --batch-size 6 --g-accum-gradients 2 --n-ctx 256 --n-embed 512 --n-head 4 --n-layer 3 --epochs 2 --log-every 100 --save-every 1000 --validate-every 1000",
#     "batch_size": 6,
#     "epochs": 2,
#     "g_accum_gradients": 2,
#     "hparams": {
#         "gradient_checkpointing": false,
#         "n_ctx": 256,
#         "n_embed": 512,
#         "n_head": 4,
#         "n_hidden": 512,
#         "n_layer": 3,
#         "n_vocab": 50000
#     },
#     "lr": 0.00025
# }
# Loading dataset from data/encoded
# Train dataset has 111,179,108 tokens
# Validation dataset has 233,689 tokens
# Resuming from seen_tokens 606,011,904
# epochs:   0%|                                             | 0/2 [00:00<?, ?it/s]
# epochs: 5it [00:00, 57143.11it/s]
#
# validation:   0%|                                       | 0/912 [00:00<?, ?it/s]
#
# ...
